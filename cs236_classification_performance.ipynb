# %% [markdown]
# # Calculate finetuned model performance on the classification task

# %% [markdown]
# ### Load in rough responses and clean them

# %%
N_EXAMPLES = 100 # we only haves results on 100 examples

# %%
import pandas as pd
import numpy as np
from sklearn import metrics

# %%
response_df = pd.read_csv("output_response.csv", names=["raw_response"], header=None)
response_df.shape
# Out:
# (100, 1)

# %%
response_df
# Out:
#                                          raw_response
# 0                                                yes.
# 1                                                yes.
# 2                                                 yes
# 3                                                yes.
# 4   summary : tailored interventions are ways to c...
# ..                                                ...
# 95  yes. cigarette taxes are passed on to consumer...
# 96  summary : vertical lines in distal esophageal ...
# 97                                               yes.
# 98                                               yes.
# 99  yes. dexamethasone is an effective alternative...
#
# [100 rows x 1 columns]

# %%
temp_df = response_df

# %%
temp_df['yes_no_maybe'] = temp_df['raw_response'].apply(lambda x: 'yes' if 'yes' in x else ('no' if 'no' in x else 'maybe'))

# %%
temp_df
# Out:
#                                          raw_response yes_no_maybe
# 0                                                yes.          yes
# 1                                                yes.          yes
# 2                                                 yes          yes
# 3                                                yes.          yes
# 4   summary : tailored interventions are ways to c...        maybe
# ..                                                ...          ...
# 95  yes. cigarette taxes are passed on to consumer...          yes
# 96  summary : vertical lines in distal esophageal ...           no
# 97                                               yes.          yes
# 98                                               yes.          yes
# 99  yes. dexamethasone is an effective alternative...          yes
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Understand the maybe

# %%
temp_df[temp_df['yes_no_maybe'] == 'maybe']
# Out:
#                                          raw_response yes_no_maybe
# 4   summary : tailored interventions are ways to c...        maybe
# 9   summary : a short stay or 23-hour ward is a ho...        maybe
# 11  summary : therapeutic anticoagulation is the u...        maybe
# 14  summary : emergency ultrasound fellowship prog...        maybe
# 20  summary : israeli hospitals are well prepared ...        maybe
# 21  summary : acute respiratory distress syndrome ...        maybe
# 37  summary : a pap smear is a test to check for c...        maybe
# 38  summary : pollen is a fine powder that comes f...        maybe
# 54  summary : a sternal fracture is a break in the...        maybe
# 56  summary : adjuvant chemotherapy is given after...        maybe
# 61  summary : depression is a common mental disord...        maybe
# 73  summary : the knee is the largest joint in the...        maybe
# 74  summary : a tibial component is the lower leg ...        maybe
# 75  summary : the protein vascular endothelial gro...        maybe
# 81  summary : aripiprazole is a medication used to...        maybe
# 88  summary : tinnitus is a ringing or buzzing sou...        maybe
# 89  summary : sputum analysis is a common test for...        maybe

# %% [markdown]
# ### Load true test set and binarize

# %%
test_df = pd.read_csv("cleaned_pubmed_qa_all.csv")
test_df.head()
# Out:
#       pubid                                        instruction  \
# 0  21645374  Do mitochondria play a role in remodelling lac...
# 1  16418930  Landolt C and snellen e acuity: differences in...
# 2   9488747  Syncope during bathing in infants, a pediatric...
# 3  17208539  Are the long-term results of the transanal pul...
# 4  10808977  Can tailored interventions increase mammograph...
#
#                                              context  \
# 0  {'contexts': ['Programmed cell death (PCD) is ...
# 1  {'contexts': ['Assessment of visual acuity dep...
# 2  {'contexts': ['Apparent life-threatening event...
# 3  {'contexts': ['The transanal endorectal pull-t...
# 4  {'contexts': ['Telephone counseling and tailor...
#
#                                          long_answer output  \
# 0  Results depicted mitochondrial dynamics in viv...    yes
# 1  Using the charts described, there was only a s...     no
# 2  "Aquagenic maladies" could be a pediatric form...    yes
# 3  Our long-term study showed significantly bette...     no
# 4  The effects of the intervention were most pron...    yes
#
#    num_characters_instruction  num_characters_output
# 0                          90                      3
# 1                          68                      2
# 2                          79                      3
# 3                         106                      2
# 4                          68                      3

# %%
def binarize(df, input_colname, output_colname):
  df[output_colname] = 0
  df.loc[df[input_colname] == "yes", output_colname] = 1
  print("Total rows:", df.shape[0])
  print("Total rows with yes:", df[df[output_colname]==1].shape[0])
  print("Total rows with no:", df[df[output_colname]==0].shape[0])
  return df

# %%
temp = test_df
temp2 = binarize(df=temp, input_colname= "output", outut_colname="y_true")
temp2
# Out:
# Total rows: 1000
# Total rows with yes: 552
# Total rows with no: 448
#         pubid                                        instruction  \
# 0    21645374  Do mitochondria play a role in remodelling lac...
# 1    16418930  Landolt C and snellen e acuity: differences in...
# 2     9488747  Syncope during bathing in infants, a pediatric...
# 3    17208539  Are the long-term results of the transanal pul...
# 4    10808977  Can tailored interventions increase mammograph...
# ..        ...                                                ...
# 995   8921484  Does gestational age misclassification explain...
# 996  16564683  Is there any interest to perform ultrasonograp...
# 997  23147106  Is peak concentration needed in therapeutic dr...
# 998  21550158  Can autologous platelet-rich plasma gel enhanc...
# 999  17559449  Are sugars-free medicines more erosive than su...
#
#                                                context  \
# 0    {'contexts': ['Programmed cell death (PCD) is ...
# 1    {'contexts': ['Assessment of visual acuity dep...
# 2    {'contexts': ['Apparent life-threatening event...
# 3    {'contexts': ['The transanal endorectal pull-t...
# 4    {'contexts': ['Telephone counseling and tailor...
# ..                                                 ...
# 995  {'contexts': ['After 34 weeks gestation, summa...
# 996  {'contexts': ['To evaluate the accuracy of ult...
# 997  {'contexts': ['We analyzed the pharmacokinetic...
# 998  {'contexts': ['This investigation assesses the...
# 999  {'contexts': ['The reduced use of sugars-conta...
#
#                                            long_answer output  \
# 0    Results depicted mitochondrial dynamics in viv...    yes
# 1    Using the charts described, there was only a s...     no
# 2    "Aquagenic maladies" could be a pediatric form...    yes
# 3    Our long-term study showed significantly bette...     no
# 4    The effects of the intervention were most pron...    yes
# ..                                                 ...    ...
# 995  Gestational age misclassification is an unlike...     no
# 996  Sonography has no place in the diagnosis of un...     no
# 997  These results suggest little need to use peak ...     no
# 998  The PRP group recorded reduced pain, swelling,...    yes
# 999  Paediatric SF medicines were not more erosive ...     no
#
#      num_characters_instruction  num_characters_output  y_true
# 0                            90                      3       1
# 1                            68                      2       0
# 2                            79                      3       1
# 3                           106                      2       0
# 4                            68                      3       1
# ..                          ...                    ...     ...
# 995                         115                      2       0
# 996                          81                      2       0
# 997                          74                      2       0
# 998                         109                      3       1
# 999                          72                      2       0
#
# [1000 rows x 8 columns]

# %% [markdown]
# ### Line up predictions and true values

# %%
score_df = temp2.head(N_EXAMPLES)
score_df['model_response'] = temp_df.yes_no_maybe
# Out:
# <ipython-input-31-6638ff924cf2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score_df['model_response'] = temp_df.yes_no_maybe

# %%
score_df = binarize(score_df, input_colname='model_response', output_colname='y_pred')
score_df
# Out:
# Total rows: 100
# Total rows with yes: 60
# Total rows with no: 40
# <ipython-input-33-273ad99c30bf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[output_colname] = 0
#        pubid                                        instruction  \
# 0   21645374  Do mitochondria play a role in remodelling lac...
# 1   16418930  Landolt C and snellen e acuity: differences in...
# 2    9488747  Syncope during bathing in infants, a pediatric...
# 3   17208539  Are the long-term results of the transanal pul...
# 4   10808977  Can tailored interventions increase mammograph...
# ..       ...                                                ...
# 95  23076787  Can increases in the cigarette tax rate be lin...
# 96   9199905  Vertical lines in distal esophageal mucosa (VL...
# 97  23999452  Does hypoglycaemia increase the risk of cardio...
# 98  22534881  Does the radiographic transition zone correlat...
# 99  24785562  Is dexamethasone an effective alternative to o...
#
#                                               context  \
# 0   {'contexts': ['Programmed cell death (PCD) is ...
# 1   {'contexts': ['Assessment of visual acuity dep...
# 2   {'contexts': ['Apparent life-threatening event...
# 3   {'contexts': ['The transanal endorectal pull-t...
# 4   {'contexts': ['Telephone counseling and tailor...
# ..                                                ...
# 95  {'contexts': ["To explain China's cigarette pr...
# 96  {'contexts': ['We observed an endoscopic abnor...
# 97  {'contexts': ['Hypoglycaemia caused by glucose...
# 98  {'contexts': ["The correlation between radiogr...
# 99  {'contexts': ['A short course of systemic cort...
#
#                                           long_answer output  \
# 0   Results depicted mitochondrial dynamics in viv...    yes
# 1   Using the charts described, there was only a s...     no
# 2   "Aquagenic maladies" could be a pediatric form...    yes
# 3   Our long-term study showed significantly bette...     no
# 4   The effects of the intervention were most pron...    yes
# ..                                                ...    ...
# 95  Numerous studies have found that taxation is o...     no
# 96  Histology usually demonstrated moderate to sev...    yes
# 97  Severe hypoglycaemia is associated with an inc...    yes
# 98  Correlation between level of radiographic tran...     no
# 99  The current literature suggests that dexametha...    yes
#
#     num_characters_instruction  num_characters_output  y_true model_response  \
# 0                           90                      3       1            yes
# 1                           68                      2       0            yes
# 2                           79                      3       1            yes
# 3                          106                      2       0            yes
# 4                           68                      3       1          maybe
# ..                         ...                    ...     ...            ...
# 95                          77                      2       0            yes
# 96                         110                      3       1             no
# 97                          62                      3       1            yes
# 98                         122                      2       0            yes
# 99                         112                      3       1            yes
#
#     y_pred
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
# ..     ...
# 95       1
# 96       0
# 97       1
# 98       1
# 99       1
#
# [100 rows x 10 columns]

# %%
print(score_df.shape)
score_df = score_df[score_df['model_response'] != 'maybe']
print(score_df.shape)
# Out:
# (100, 10)
# (83, 10)

# %% [markdown]
# ### Score the model

# %%
metrics.accuracy_score(y_true=score_df['y_true'], y_pred=score_df['y_pred'])
# Out:
# 0.5421686746987951

# %%
metrics.precision_score(y_true=score_df['y_true'], y_pred=score_df['y_pred'])
# Out:
# 0.5833333333333334

# %%
metrics.recall_score(y_true=score_df['y_true'], y_pred=score_df['y_pred'])
# Out:
# 0.7291666666666666
